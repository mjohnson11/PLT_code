# %%
import pandas as pd
from glob import glob
import numpy as np

# %%
d = pd.read_csv('all_read_files.csv')
r1_files = [i for i in d['Filename'] if 'R1.' in i or 'R1_001.' in i]
d.head()
# Out:
#                                            Filename size
# 0  dBFA2-02M_NaCl_2N-R1-Subpool_S33_R1_001.fastq.gz  37M
# 1       dBFA2-21C_2N-R1-Subpool_S32_R1_001.fastq.gz  28M
# 2      dBFA2-FLC4_2N-R1-Subpool_S34_R1_001.fastq.gz  12M
# 3         dBFA2_h1_Ancestor_YPD_2N_R1_1_R1.fastq.gz  23M
# 4         dBFA2_h1_Ancestor_YPD_2N_R1_1_R2.fastq.gz  23M

# %%
flist = glob('demult_maps/*/*.csv')
ds = {f.split('/')[-1]: pd.read_csv(f) for f in flist}
dnames = sorted(list(ds.keys()))
df_rec = []
for dn in ds:
    ds[dn]['File'] = dn
    ds[dn] = ds[dn].rename(columns={'Inline_index': 'R1_index'})
    df_rec.append(ds[dn])
    
alldf = pd.concat(df_rec)
file_to_run = {
    'Harvard_dip_all.csv': 'Harvard_dip_LT_',
    'Stanford_hap_all.csv': 'Stanford_hap_LT_',
    'Stanford_high_all.csv': 'Stanford_high_LT_',
    'Stanford_mid_all.csv': 'Stanford_mid_LT_',
    'Stanford_redos_all.csv': 'Stanford_redos_LT_',
    'Stanford_restart_all.csv': 'Stanford_restart_LT_',
    'dBFA2_Harvard_1_indices.csv': 'dBFA2_h1_',
    'dBFA2_Stanford_1_indices.csv': 'dBFA2_s1_',
    'dBFA2_Stanford_2_indices.csv': 'dBFA2_s2_',
    'hBFA1_part1_indices.csv': 'hBFA1_h1_',
    'hBFA1_part2_indices.csv': 'hBFA1_h2_',
    'hBFA2_Harvard_1_indices.csv': 'hBFA2_h1_',
    'hBFA2_Stanford_indices.csv': 'hBFA2_s_',
    'hBFA2_dBFA2_Harvard_2_combined_indices.csv': 'hBFA2_dBFA2_h2_',
    'hBFA1_subpool_demult.csv': '',
    'hBFA2_subpool_demult.csv': '',
    'dBFA2_subpool_demult.csv': ''
}

def get_file(row):
    normal_file = row['Run']+row['Library']+'_R1.fastq.gz'
    if normal_file in r1_files:
        return normal_file
    else:
        found_file = [i for i in r1_files if row['Run']+row['Library'] in i]
        #print(row['Run']+row['Library'], found_file)
        assert len(found_file) == 1
        return found_file[0]

alldf['Run'] = alldf['File'].map(file_to_run)
alldf['R1_files'] = alldf.apply(get_file, axis=1)
lib_to_file = alldf[['Library', 'R1_files']].groupby('Library').agg(lambda x: ';'.join(x)).reset_index()
lib_to_file.head()
# Out:
# /n/home13/mjohnson/anaconda3/envs/milo_py37/lib/python3.7/site-packages/ipykernel_launcher.py:10: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   # Remove the CWD from sys.path while we load stuff.
#                   Library                                           R1_files
# 0    02M_NaCl_2N-R1-Time0  Stanford_high_LT_02M_NaCl_2N-R1-Time0_R1.fastq.gz
# 1  02M_NaCl_2N-R1-Time104  Stanford_high_LT_02M_NaCl_2N-R1-Time104_R1.fas...
# 2  02M_NaCl_2N-R1-Time112  Stanford_high_LT_02M_NaCl_2N-R1-Time112_R1.fas...
# 3  02M_NaCl_2N-R1-Time128  Stanford_high_LT_02M_NaCl_2N-R1-Time128_R1.fas...
# 4  02M_NaCl_2N-R1-Time144  Stanford_high_LT_02M_NaCl_2N-R1-Time144_R1.fas...

# %%
td = d.merge(alldf, left_on='Filename', right_on='R1_files', how='inner')
td[['Filename', 'Library', 'R1_index', 'R1_bp_to_BC', 'R2_index', 'R2_bp_to_BC']].to_csv('All_file_primer_info.csv', index=False)

# %%
def fix_lib(lib):
    if ('Subpool' in lib or 'Ancestor' in lib) and 'BFA' not in lib:
        if 'Ancestor' in lib:
            lib = lib.replace('YPD_2N', 'YPDAnc_2N').replace('Ancestor', 'Subpool')
        lib = lib.replace('_R', '-R')
        return 'dBFA2-'+lib[lib.index('_')+1:]+'-'+lib.split('_')[0]
    else:
        return lib

lib_to_file['Library'] = lib_to_file['Library'].apply(fix_lib)
lib_to_file[lib_to_file['Library'].apply(lambda l: 'Subpool' in l)]
# Out:
#                              Library  \
# 127     dBFA2-YPDAnc_2N-R1_1-Subpool
# 128     dBFA2-YPDAnc_2N-R1_2-Subpool
# 270     dBFA2-02M_NaCl_2N-R2-Subpool
# 271          dBFA2-21C_2N-R2-Subpool
# 272          dBFA2-37C_2N-R1-Subpool
# 273          dBFA2-37C_2N-R2-Subpool
# 274         dBFA2-48Hr_2N-R1-Subpool
# 275         dBFA2-48Hr_2N-R2-Subpool
# 276          dBFA2-CLM_2N-R1-Subpool
# 277          dBFA2-CLM_2N-R2-Subpool
# 278         dBFA2-FLC4_2N-R2-Subpool
# 279      dBFA2-GlyEtOH_2N-R1-Subpool
# 280      dBFA2-GlyEtOH_2N-R2-Subpool
# 281           dBFA2-SC_2N-R1-Subpool
# 282           dBFA2-SC_2N-R2-Subpool
# 283          dBFA2-YPD_2N-R1-Subpool
# 284          dBFA2-YPD_2N-R2-Subpool
# 285        dBFA2-pH3_8_2N-R1-Subpool
# 286        dBFA2-pH3_8_2N-R2-Subpool
# 287        dBFA2-pH7_3_2N-R1-Subpool
# 288        dBFA2-pH7_3_2N-R2-Subpool
# 320     dBFA2-02M_NaCl_2N-R1-Subpool
# 336          dBFA2-21C_2N-R1-Subpool
# 399         dBFA2-FLC4_2N-R1-Subpool
# 486       hBFA1-21C_alpha-R1-Subpool
# 487       hBFA1-21C_alpha-R2-Subpool
# 496       hBFA1-37C_alpha-R1-Subpool
# 497       hBFA1-37C_alpha-R2-Subpool
# 506       hBFA1-CLM_alpha-R1-Subpool
# 507       hBFA1-CLM_alpha-R2-Subpool
# 512      hBFA1-FLC4_alpha-R1-Subpool
# 513      hBFA1-FLC4_alpha-R2-Subpool
# 522   hBFA1-GlyEtOH_alpha-R1-Subpool
# 524   hBFA1-GlyEtOH_alpha-R2-Subpool
# 535        hBFA1-SC_alpha-R1-Subpool
# 536        hBFA1-SC_alpha-R2-Subpool
# 545       hBFA1-YPD_alpha-R1-Subpool
# 546       hBFA1-YPD_alpha-R2-Subpool
# 555     hBFA1-pH3_8_alpha-R1-Subpool
# 556     hBFA1-pH3_8_alpha-R2-Subpool
# 565     hBFA1-pH7_3_alpha-R1-Subpool
# 566     hBFA1-pH7_3_alpha-R2-Subpool
# 582  hBFA2-02M_NaCl_alpha-R1-Subpool
# 598  hBFA2-08M_NaCl_alpha-R2-Subpool
# 614       hBFA2-21C_alpha-R1-Subpool
# 630       hBFA2-37C_alpha-R1-Subpool
# 653          hBFA2-CLM_2N-R1-Subpool
# 654       hBFA2-CLM_alpha-R1-Subpool
# 670         hBFA2-FLC4_2N-R1-Subpool
# 671      hBFA2-FLC4_alpha-R1-Subpool
# 687      hBFA2-GlyEtOH_2N-R1-Subpool
# 688   hBFA2-GlyEtOH_alpha-R1-Subpool
# 704        hBFA2-SC_alpha-R1-Subpool
# 720       hBFA2-YPD_alpha-R1-Subpool
# 736     hBFA2-pH3_8_alpha-R1-Subpool
# 752     hBFA2-pH7_3_alpha-R1-Subpool
#
#                                               R1_files
# 127          dBFA2_h1_Ancestor_YPD_2N_R1_1_R1.fastq.gz
# 128          dBFA2_h1_Ancestor_YPD_2N_R1_2_R1.fastq.gz
# 270        dBFA2_h1_Subpool_02M_NaCl_2N_R2_R1.fastq.gz
# 271             dBFA2_h1_Subpool_21C_2N_R2_R1.fastq.gz
# 272             dBFA2_h1_Subpool_37C_2N_R1_R1.fastq.gz
# 273             dBFA2_h1_Subpool_37C_2N_R2_R1.fastq.gz
# 274            dBFA2_h1_Subpool_48Hr_2N_R1_R1.fastq.gz
# 275            dBFA2_h1_Subpool_48Hr_2N_R2_R1.fastq.gz
# 276             dBFA2_h1_Subpool_CLM_2N_R1_R1.fastq.gz
# 277             dBFA2_h1_Subpool_CLM_2N_R2_R1.fastq.gz
# 278            dBFA2_h1_Subpool_FLC4_2N_R2_R1.fastq.gz
# 279         dBFA2_h1_Subpool_GlyEtOH_2N_R1_R1.fastq.gz
# 280         dBFA2_h1_Subpool_GlyEtOH_2N_R2_R1.fastq.gz
# 281              dBFA2_h1_Subpool_SC_2N_R1_R1.fastq.gz
# 282              dBFA2_h1_Subpool_SC_2N_R2_R1.fastq.gz
# 283             dBFA2_h1_Subpool_YPD_2N_R1_R1.fastq.gz
# 284             dBFA2_h1_Subpool_YPD_2N_R2_R1.fastq.gz
# 285           dBFA2_h1_Subpool_pH3_8_2N_R1_R1.fastq.gz
# 286           dBFA2_h1_Subpool_pH3_8_2N_R2_R1.fastq.gz
# 287           dBFA2_h1_Subpool_pH7_3_2N_R1_R1.fastq.gz
# 288           dBFA2_h1_Subpool_pH7_3_2N_R2_R1.fastq.gz
# 320   dBFA2-02M_NaCl_2N-R1-Subpool_S33_R1_001.fastq.gz
# 336        dBFA2-21C_2N-R1-Subpool_S32_R1_001.fastq.gz
# 399       dBFA2-FLC4_2N-R1-Subpool_S34_R1_001.fastq.gz
# 486     hBFA1-21C_alpha-R1-Subpool_S18_R1_001.fastq.gz
# 487     hBFA1-21C_alpha-R2-Subpool_S19_R1_001.fastq.gz
# 496      hBFA1-37C_alpha-R1-Subpool_S8_R1_001.fastq.gz
# 497      hBFA1-37C_alpha-R2-Subpool_S9_R1_001.fastq.gz
# 506     hBFA1-CLM_alpha-R1-Subpool_S16_R1_001.fastq.gz
# 507     hBFA1-CLM_alpha-R2-Subpool_S17_R1_001.fastq.gz
# 512    hBFA1-FLC4_alpha-R1-Subpool_S14_R1_001.fastq.gz
# 513    hBFA1-FLC4_alpha-R2-Subpool_S15_R1_001.fastq.gz
# 522  hBFA1-GlyEtOH_alpha-R1-Subpool_S36_R1_001.fast...
# 524  hBFA1-GlyEtOH_alpha-R2-Subpool_S37_R1_001.fast...
# 535       hBFA1-SC_alpha-R1-Subpool_S6_R1_001.fastq.gz
# 536       hBFA1-SC_alpha-R2-Subpool_S7_R1_001.fastq.gz
# 545      hBFA1-YPD_alpha-R1-Subpool_S4_R1_001.fastq.gz
# 546      hBFA1-YPD_alpha-R2-Subpool_S5_R1_001.fastq.gz
# 555   hBFA1-pH3_8_alpha-R1-Subpool_S10_R1_001.fastq.gz
# 556   hBFA1-pH3_8_alpha-R2-Subpool_S11_R1_001.fastq.gz
# 565   hBFA1-pH7_3_alpha-R1-Subpool_S12_R1_001.fastq.gz
# 566   hBFA1-pH7_3_alpha-R2-Subpool_S13_R1_001.fastq.gz
# 582  hBFA2-02M_NaCl_alpha-R1-Subpool_S28_R1_001.fas...
# 598  hBFA2-08M_NaCl_alpha-R2-Subpool_S29_R1_001.fas...
# 614     hBFA2-21C_alpha-R1-Subpool_S31_R1_001.fastq.gz
# 630     hBFA2-37C_alpha-R1-Subpool_S24_R1_001.fastq.gz
# 653        hBFA2-CLM_2N-R1-Subpool_S40_R1_001.fastq.gz
# 654     hBFA2-CLM_alpha-R1-Subpool_S26_R1_001.fastq.gz
# 670       hBFA2-FLC4_2N-R1-Subpool_S27_R1_001.fastq.gz
# 671    hBFA2-FLC4_alpha-R1-Subpool_S30_R1_001.fastq.gz
# 687    hBFA2-GlyEtOH_2N-R1-Subpool_S35_R1_001.fastq.gz
# 688  hBFA2-GlyEtOH_alpha-R1-Subpool_S25_R1_001.fast...
# 704      hBFA2-SC_alpha-R1-Subpool_S21_R1_001.fastq.gz
# 720     hBFA2-YPD_alpha-R1-Subpool_S20_R1_001.fastq.gz
# 736   hBFA2-pH3_8_alpha-R1-Subpool_S23_R1_001.fastq.gz
# 752   hBFA2-pH7_3_alpha-R1-Subpool_S22_R1_001.fastq.gz

# %%
for bfa in ['dBFA2', 'hBFA2', 'hBFA1']:
    td = lib_to_file[lib_to_file['Library'].apply(lambda l: bfa in l)]
    print(bfa, len(td))
    td.to_csv('assay_files/'+bfa+'_assay.csv', index=False)
# Out:
# dBFA2 194
# hBFA2 186
# hBFA1 89

# %%
lt = lib_to_file[lib_to_file['Library'].apply(lambda l: 'BFA' not in l and 'Ancestor' not in l and 'Subpool' not in l)]
env_reps = sorted(set([i.split('-Time')[0] for i in lt['Library']]))
for er in env_reps:
    td = lt[lt['Library'].apply(lambda l: l.split('-Time')[0]==er)]
    #print(er, len(td))
    td.to_csv('assay_files/LT_'+er+'_assay.csv', index=False)

# %%
file_dict = dict()
all_assay_files = glob('assay_files/*.csv')
for f in all_assay_files:
    for j, row in pd.read_csv(f).iterrows():
        for fname in row['R1_files'].split(';'):
            assert fname not in file_dict
            file_dict[fname] = [row['Library'], f.split('/')[-1]]

# %%
len(r1_files), len(file_dict), len(set(file_dict.keys()).intersection(set(r1_files)))
# Out:
# (793, 793, 793)

# %%
mat = []
for f in all_assay_files:
    td = pd.read_csv(f)
    td['Assay'] = f.split('/')[-1].split('_assay')[0]
    mat.append(td)
    
def get_r2(r1):
    r2s = []
    for f in r1.split(';'):
        r2 = ''
        if 'R1.fastq.gz' in f:
            r2_tmp = f.replace('R1.fastq.gz', 'R2.fastq.gz')
            if r2_tmp in list(d['Filename']):
                r2 = r2_tmp
        r2s.append(r2)
    return ';'.join(r2s)
    
assay_info = pd.concat(mat)
assay_info['R2_files'] = assay_info['R1_files'].apply(get_r2)
assay_info[['Assay', 'Library', 'R1_files', 'R2_files']].to_csv('Files_by_assay.csv', index=False)

# %%
assay_info[['Assay']].drop_duplicates().to_csv('All_assays.txt', index=False, header=None)
